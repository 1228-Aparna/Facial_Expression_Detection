# %%
#importing all the required libraries
import numpy as np
import pandas as pd
#importing both the datasets
songmetadata = pd.read_csv(r'C:/Users/admin/Downloads/abc.csv')

song_df = songmetadata
#writing the file in .csv to visualize in Tableau
song_df.to_csv(r'C:\Users\admin\Downloads\data.csv', index = False)
song_df
# Out:
#      Unnamed: 0              Senorita  Zindagi Na Milegi Dobara  \
# 0           NaN     Mareez - E - Ishq                       Zid
# 1           NaN           Subhanallah    Yeh Jawani Hai Deewani
# 2           NaN                 Ilahi    Yeh Jawani Hai Deewani
# 3           NaN        Balam Pichkari  Yeh Jawaani Hai Deewani
# 4           NaN              Ghungroo                       War
# ..          ...                   ...                       ...
# 120         NaN         Dheere Dheere                       NaN
# 121         NaN               Baarish                       NaN
# 122         NaN  Ashiqui Banayaa Apne                       NaN
# 123         NaN        Afreen Afreen                        NaN
# 124         NaN            Aaj Sajeya                       NaN
#
#             Unnamed: 3
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 120  yo yo honey singh
# 121                NaN
# 122                NaN
# 123                NaN
# 124                NaN
#
# [125 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# <ipython-input-18-98d940843c25> in _repr_html_(self)
#       1 class Clickable:
#       2         def _repr_html_(self):
# ----> 3                 return f'<a href="{url}">{text}</a>'
#       4 Clickable()
#
# NameError: name 'url' is not defined

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2
def clickable(colval):
    return f'<a href="{http://www.youtube.com/}">{text}</a>' 
emotion =  ['Anger', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

model = keras.models.load_model("C:/Users/admin/Downloads/model.h5")
font = cv2.FONT_HERSHEY_SIMPLEX
cam = cv2.VideoCapture(0)
face_cas = cv2.CascadeClassifier('C:/Users/admin/Downloads/frontalface.xml')
vid = cv2.VideoCapture(0)
#a = 0
while(True):
    #a = a + 1
    ret,frame = vid.read()
    cv2.imshow("Capturing the image for cartoonifying",frame)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
    cv2.imwrite("snap.jpg",frame)
vid.release()
cv2.destroyAllWindows()
while True:
    ret, frame = cam.read()  
    if ret==True:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        #gray = cv2.flip(gray,1)
        faces = face_cas.detectMultiScale(gray, 1.3,5)
        
        for (x, y, w, h) in faces:
            face_component = gray[y:y+h, x:x+w]
            fc = cv2.resize(face_component, (48, 48))
            inp = np.reshape(fc,(1,48,48,1)).astype(np.float32)
            inp = inp/255.
            prediction = model.predict_proba(inp)
            #print(prediction)
            em = emotion[np.argmax(prediction)]
            score = np.max(prediction)
            cv2.putText(frame, em+"  "+str(score*100)+'%', (x, y), font, 1, (0, 255, 0), 2)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)
        cv2.imshow("image", frame)
        
        if cv2.waitKey(1) == ord('q'):
            break
    else:
        print ('Error')

cam.release()
cv2.destroyAllWindows()
x = True
while x:
    # Reading the Image 
    image = cv2.imread("snap.jpg")
    # Finding the Edges of Image
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
    gray = cv2.medianBlur(gray, 7) 
    edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 10)
    # Making a Cartoon of the image
    #first transformation
    color = cv2.bilateralFilter(image, 12, 250, 250) 
    cartoon = cv2.bitwise_and(color, color, mask=edges)
    #second transformation
    #In the second transformation, we will try to blur the image with an edge-preserving filter and 
    #adding a threshold to the edges. For this, we will use Gaussian Blur.
    grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #apply gaussian blur
    grayImage = cv2.GaussianBlur(grayImage, (3, 3), 0)
    #detect edges
    edgeImage = cv2.Laplacian(grayImage
                              , -1, ksize=5)
    edgeImage = 255 - edgeImage
    #threshold image
    ret, edgeImage = cv2.threshold(edgeImage, 150, 255, cv2.THRESH_BINARY)
    #blur images heavily using edgePreservingFilter
    edgePreservingImage = cv2.edgePreservingFilter(image, flags=2, sigma_s=50, sigma_r=0.4)
    #create output matrix
    output =np.zeros(grayImage.shape)
    #combine cartoon image and edges image
    output = cv2.bitwise_and(edgePreservingImage, edgePreservingImage, mask=edgeImage)
    #cartoon image 
    cv2.imshow("Cartoon", output) 
    cv2.waitKey(0) #Used to close the image window using '0'
    cv2.destroyAllWindows()
    x = False

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8C02-2A61
#
#  Directory of C:\Users\admin
#
# 11/20/2022  09:04 PM    <DIR>          .
# 11/20/2022  09:04 PM    <DIR>          ..
# 07/29/2022  11:31 AM    <DIR>          .android
# 10/24/2021  01:34 PM               146 .angular-config.json
# 12/22/2021  10:35 AM                 5 .bash_history
# 06/11/2021  02:07 PM    <DIR>          .cache
# 11/20/2022  09:07 PM    <DIR>          .conda
# 05/18/2021  04:56 PM                25 .condarc
# 06/09/2021  10:47 AM    <DIR>          .config
# 05/18/2021  04:55 PM    <DIR>          .continuum
# 03/16/2022  04:26 PM             3,150 .dbshell
# 12/22/2021  10:20 PM    <DIR>          .eclipse
# 05/20/2022  09:13 PM                16 .emulator_console_auth_token
# 12/22/2021  11:14 AM               122 .gitconfig
# 07/25/2022  08:53 AM    <DIR>          .gradle
# 03/23/2021  07:57 PM    <DIR>          .idlerc
# 11/13/2022  10:19 AM    <DIR>          .ipynb_checkpoints
# 05/18/2021  04:57 PM    <DIR>          .ipython
# 05/21/2021  01:32 PM    <DIR>          .jupyter
# 05/18/2021  05:09 PM    <DIR>          .keras
# 12/24/2021  10:58 PM    <DIR>          .lemminx
# 12/22/2021  11:14 AM                20 .lesshst
# 12/24/2021  10:58 PM    <DIR>          .m2
# 05/18/2021  09:48 PM    <DIR>          .matplotlib
# 10/20/2021  10:05 AM                 0 .mongorc.js
# 06/16/2021  10:32 AM                 0 .node_repl_history
# 08/01/2022  03:40 PM    <DIR>          .p2
# 11/13/2022  10:20 AM                 0 .python_history
# 01/31/2020  09:38 PM    <DIR>          .ssh
# 06/09/2021  10:39 AM    <DIR>          .vscode
# 12/28/2021  04:16 PM            21,497 _viminfo
# 09/22/2020  01:43 PM    <DIR>          3D Objects
# 05/19/2021  05:30 PM            29,046 abc.jpg
# 02/26/2022  08:55 PM             1,484 age.html
# 05/21/2021  04:11 PM    <DIR>          anaconda3
# 07/29/2022  09:24 AM    <DIR>          AndroidStudioProjects
# 04/24/2022  05:45 PM            20,426 Assignment - KNN and SVM (1).ipynb
# 11/10/2022  11:18 PM             3,128 Bollywood Dataset - Happy.csv
# 11/10/2022  11:18 PM             3,508 Bollywood Dataset - Sad.csv
# 10/13/2022  01:23 AM    <DIR>          chat_model
# 10/13/2022  01:27 AM            70,675 CHATBOT.ipynb
# 10/24/2021  12:46 PM             8,829 code (1).ipynb
# 10/24/2021  12:45 PM             9,006 code (2).ipynb
# 10/24/2021  12:01 PM             9,276 code.ipynb
# 09/22/2020  01:44 PM    <DIR>          Contacts
# 11/20/2022  06:14 PM    <DIR>          Creative Cloud Files
# 06/17/2021  03:54 PM    <DIR>          Creative Cloud Files parasaaparna1@gmail.com 493093bc7dbf70882b37f3cfcd69607b0a3e3a96cc1f1392da07a1a7e66f953d
# 11/13/2022  06:22 PM    <DIR>          Desktop
# 11/11/2022  03:10 PM    <DIR>          Documents
# 11/20/2022  07:20 PM    <DIR>          Downloads
# 12/25/2021  12:38 PM    <DIR>          eclipse
# 12/25/2021  03:34 PM    <DIR>          eclipse-workspace
# 04/18/2022  08:45 PM            48,580 EDA on IPL Dataset.ipynb
# 10/24/2019  02:59 PM        10,425,344 exercism.exe
# 03/18/2022  09:14 PM            71,145 facial-expression-recognition-using-cnn (1) (1).ipynb
# 09/22/2020  01:44 PM    <DIR>          Favorites
# 04/24/2022  05:17 PM        11,686,383 fraud_data.csv
# 03/25/2021  12:32 AM         1,927,630 get-pip.py
# 03/11/2022  03:32 PM    <DIR>          GoogleAuthen
# 11/13/2022  10:55 AM           341,406 haarcascade_eye.xml
# 11/13/2022  10:55 AM           930,127 haarcascade_frontalface_default.xml
# 01/02/2022  11:17 AM    <DIR>          HP
# 10/13/2022  01:21 AM             1,941 intents.json
# 04/18/2022  08:44 PM            48,580 IPL Dataset - Analysis and Visualisation-Exercise.ipynb
# 04/13/2022  08:42 PM           150,820 IPL Matches 2008-2020.csv
# 10/13/2022  01:23 AM               634 label_encoder.pickle
# 10/23/2019  08:15 PM             1,088 LICENSE
# 09/22/2020  01:44 PM    <DIR>          Links
# 11/11/2022  09:53 PM            25,813 MINI.ipynb
# 05/20/2021  12:53 PM             5,258 Ml expression detection .ipynb
# 11/20/2022  08:53 PM            13,073 ML_detect_expression_cartoonify.ipynb
# 05/21/2021  06:31 PM        45,958,688 model.h5
# 10/24/2021  11:48 AM            22,905 Moth_Eradication.ipynb
# 09/22/2020  01:44 PM    <DIR>          Music
# 03/11/2022  01:58 PM    <DIR>          node_modules
# 07/15/2022  10:39 PM    <DIR>          OneDrive
# 11/13/2022  02:39 PM             5,760 output.mp3
# 03/11/2022  01:58 PM               897 package-lock.json
# 06/12/2022  11:05 AM    <DIR>          Pictures
# 03/03/2022  07:37 PM    <DIR>          PycharmProjects
# 11/20/2022  09:04 PM               835 README.md
# 04/18/2022  08:57 PM            17,397 Regression_Assignment.ipynb
# 12/01/2019  07:25 PM    <DIR>          Roaming
# 11/13/2022  04:20 PM            15,531 sample mini project .ipynb
# 09/22/2020  01:44 PM    <DIR>          Saved Games
# 07/19/2021  03:03 PM    <DIR>          Searches
# 07/01/2021  08:24 PM    <DIR>          shell
# 11/20/2022  08:17 PM            94,052 snap.jpg
# 03/14/2022  03:06 PM             3,236 test.html
# 12/28/2021  07:52 PM               187 test.php
# 10/05/2021  03:00 PM               202 test.py
# 10/13/2022  01:23 AM             1,650 tokenizer.pickle
# 07/12/2021  10:06 AM    <DIR>          Tracing
# 04/13/2022  08:23 PM                72 Untitled.ipynb
# 03/13/2022  06:23 PM    <DIR>          uploads
# 12/29/2021  11:06 AM             2,448 validation.js
# 12/22/2021  09:13 PM    <DIR>          Videos
#               49 File(s)     71,982,041 bytes
#               48 Dir(s)  294,320,881,664 bytes free
